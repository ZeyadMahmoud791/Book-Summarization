# %%
# !pip install -q -U \
    transformers[torch]==4.40.2 \
    datasets==2.19.1 \
    evaluate==0.4.2 \
    rouge_score==0.1.2 \
    sentencepiece==0.2.0 \
    accelerate==0.30.1
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 18.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 28.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 6.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 50.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 27.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 23.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 47.9 MB/s eta 0:00:00
#   Building wheel for rouge_score (setup.py) ... done

# %%
import datasets
import evaluate
import nltk
import numpy as np
import transformers

# %%
# !git lfs install
# !git clone https://huggingface.co/booksouls/pegasus-xsum
# Out:
# Git LFS initialized.
# Cloning into 'pegasus-xsum'...
# remote: Enumerating objects: 146, done.
# remote: Counting objects: 100% (143/143), done.
# remote: Compressing objects: 100% (143/143), done.
# remote: Total 146 (delta 44), reused 0 (delta 0), pack-reused 3 (from 1)
# Receiving objects: 100% (146/146), 2.85 MiB | 11.50 MiB/s, done.
# Resolving deltas: 100% (44/44), done.
# Filtering content: 100% (18/18), 4.25 GiB | 45.00 MiB/s, done.

# %%
MODEL_NAME = "pegasus-xsum"
MAX_SOURCE_LENGTH = 512
MAX_TARGET_LENGTH = 256

# %%
dataset = datasets.load_dataset("booksouls/booksum-cleaned")
# Out:
# Downloading readme:   0%|          | 0.00/642 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/103M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/16.1M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/15.5M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/8145 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1259 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1215 [00:00<?, ? examples/s]

# %%
tokenizer = transformers.AutoTokenizer.from_pretrained(MODEL_NAME)

# %%
model = transformers.AutoModelForSeq2SeqLM.from_pretrained(MODEL_NAME)

# %%
def tokenize(books):
    result = tokenizer(
        books["chapter"],
        max_length=MAX_SOURCE_LENGTH,
        padding="max_length",
        truncation=True,
    )
    labels = tokenizer(
        text_target=books["summary"],
        max_length=MAX_TARGET_LENGTH,
        padding="max_length",
        truncation=True,
    )
    result["labels"] = labels["input_ids"]
    return result

tokenized_dataset = dataset.map(
    tokenize,
    batched=True,
    remove_columns=["chapter", "summary"]
)
# Out:
# Map:   0%|          | 0/8145 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1259 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1215 [00:00<?, ? examples/s]

# %%
rouge = evaluate.load("rouge")
# Out:
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
def postprocess_output(output):
    return [
        # rouge-Lsum expects newline after each sentence.
        "\n".join(nltk.sent_tokenize(text.strip()))
        for text in output
    ]

def compute_metrics(eval_prediction):
    predictions, labels = eval_prediction
    if isinstance(predictions, tuple):
        predictions = predictions[0]

    # Replace -100s used for padding as we can't decode them.
    predictions = np.where(predictions != -100, predictions, tokenizer.pad_token_id)
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)

    predictions_decoded = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    labels_decoded = tokenizer.batch_decode(labels, skip_special_tokens=True)

    result = rouge.compute(
        predictions=postprocess_output(predictions_decoded),
        references=postprocess_output(labels_decoded),
        use_stemmer=True,
    )

    result["gen_len"] = np.mean([
        np.count_nonzero(prediction != tokenizer.pad_token_id)
        for prediction in predictions
    ])

    return {
        key: round(value, 6)
        for key, value in result.items()
    }

# %%
training_args = transformers.Seq2SeqTrainingArguments(
    output_dir=MODEL_NAME,
    per_device_train_batch_size=2,
    per_device_eval_batch_size=2,
    gradient_accumulation_steps=64,
    num_train_epochs=10,
    evaluation_strategy="epoch",
    logging_strategy="epoch",
    save_strategy="epoch",
    predict_with_generate=True,
    push_to_hub=True,
    hub_strategy="checkpoint",
)

optimizer = transformers.Adafactor(
    model.parameters(),
    lr=1e-4,
    scale_parameter=False,
    relative_step=False,
)

trainer = transformers.Seq2SeqTrainer(
    model=model,
    tokenizer=tokenizer,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["validation"],
    compute_metrics=compute_metrics,
    optimizers=(optimizer, None),
)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='105' max='630' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [105/630 2:57:02 < 15:02:22, 0.01 it/s, Epoch 1.63/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.304900</td>
#       <td>3.789676</td>
#       <td>0.237924</td>
#       <td>0.032123</td>
#       <td>0.148748</td>
#       <td>0.205741</td>
#       <td>247.694202</td>
#     </tr>
#   </tbody>
# </table><p>
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 256, 'num_beams': 8, 'length_penalty': 0.6, 'forced_eos_token_id': 1}

# %%
trainer.train(resume_from_checkpoint=f"{MODEL_NAME}/last-checkpoint")
# Out:
# There were missing keys in the checkpoint model loaded: ['model.encoder.embed_tokens.weight', 'model.decoder.embed_tokens.weight', 'lm_head.weight'].
#     <div>
#
#       <progress value='127' max='630' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [127/630 59:52 < 8:05:48, 0.02 it/s, Epoch 1.99/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='529' max='630' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [529/630 1:06:40 < 12:45, 0.13 it/s]
#     </div>
#     <div>
#
#       <progress value='132' max='630' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [132/630 2:26:00 < 18:05:12, 0.01 it/s, Epoch 2.07/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.696200</td>
#       <td>2.995634</td>
#       <td>0.248096</td>
#       <td>0.034499</td>
#       <td>0.159467</td>
#       <td>0.213062</td>
#       <td>252.779190</td>
#     </tr>
#   </tbody>
# </table><p>
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 256, 'num_beams': 8, 'length_penalty': 0.6, 'forced_eos_token_id': 1}

# %%
trainer.train(resume_from_checkpoint=f"{MODEL_NAME}/last-checkpoint")
# Out:
# There were missing keys in the checkpoint model loaded: ['model.encoder.embed_tokens.weight', 'model.decoder.embed_tokens.weight', 'lm_head.weight'].
#     <div>
#
#       <progress value='194' max='630' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [194/630 2:25:54 < 16:03:53, 0.01 it/s, Epoch 3.05/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2</td>
#       <td>3.029200</td>
#       <td>2.694836</td>
#       <td>0.256644</td>
#       <td>0.036827</td>
#       <td>0.160481</td>
#       <td>0.221700</td>
#       <td>252.403495</td>
#     </tr>
#   </tbody>
# </table><p>
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 256, 'num_beams': 8, 'length_penalty': 0.6, 'forced_eos_token_id': 1}

# %%
trainer.train(resume_from_checkpoint=f"{MODEL_NAME}/last-checkpoint")
# Out:
# There were missing keys in the checkpoint model loaded: ['model.encoder.embed_tokens.weight', 'model.decoder.embed_tokens.weight', 'lm_head.weight'].
#     <div>
#
#       <progress value='278' max='630' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [278/630 2:41:14 < 10:52:24, 0.01 it/s, Epoch 4.38/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3</td>
#       <td>2.830200</td>
#       <td>2.661316</td>
#       <td>0.264978</td>
#       <td>0.037959</td>
#       <td>0.158569</td>
#       <td>0.230960</td>
#       <td>252.957109</td>
#     </tr>
#   </tbody>
# </table><p>
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 256, 'num_beams': 8, 'length_penalty': 0.6, 'forced_eos_token_id': 1}

# %%
trainer.train(resume_from_checkpoint=f"{MODEL_NAME}/last-checkpoint")
# Out:
# There were missing keys in the checkpoint model loaded: ['model.encoder.embed_tokens.weight', 'model.decoder.embed_tokens.weight', 'lm_head.weight'].
#     <div>
#
#       <progress value='374' max='630' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [374/630 3:19:09 < 7:04:51, 0.01 it/s, Epoch 5.90/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>4</td>
#       <td>2.778900</td>
#       <td>2.641690</td>
#       <td>0.267058</td>
#       <td>0.039428</td>
#       <td>0.161049</td>
#       <td>0.233480</td>
#       <td>252.521048</td>
#     </tr>
#   </tbody>
# </table><p>
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 256, 'num_beams': 8, 'length_penalty': 0.6, 'forced_eos_token_id': 1}
#     <div>
#
#       <progress value='380' max='630' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [380/630 3:24:55 < 6:46:35, 0.01 it/s, Epoch 6.00/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>4</td>
#       <td>2.778900</td>
#       <td>2.641690</td>
#       <td>0.267058</td>
#       <td>0.039428</td>
#       <td>0.161049</td>
#       <td>0.233480</td>
#       <td>252.521048</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='62' max='630' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 62/630 07:56 < 1:13:57, 0.13 it/s]
#     </div>

# %%
trainer.train(resume_from_checkpoint=f"{MODEL_NAME}/last-checkpoint")
# Out:
# There were missing keys in the checkpoint model loaded: ['model.encoder.embed_tokens.weight', 'model.decoder.embed_tokens.weight', 'lm_head.weight'].
#     <div>
#
#       <progress value='421' max='630' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [421/630 3:06:39 < 6:15:06, 0.01 it/s, Epoch 6.65/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>2.748600</td>
#       <td>2.629568</td>
#       <td>0.262943</td>
#       <td>0.039119</td>
#       <td>0.159378</td>
#       <td>0.229928</td>
#       <td>253.563145</td>
#     </tr>
#   </tbody>
# </table><p>
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 256, 'num_beams': 8, 'length_penalty': 0.6, 'forced_eos_token_id': 1}

# %%
trainer.train(resume_from_checkpoint=f"{MODEL_NAME}/last-checkpoint")
# Out:
# There were missing keys in the checkpoint model loaded: ['model.encoder.embed_tokens.weight', 'model.decoder.embed_tokens.weight', 'lm_head.weight'].
#     <div>
#
#       <progress value='506' max='630' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [506/630 3:15:44 < 3:12:37, 0.01 it/s, Epoch 8.00/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>6</td>
#       <td>2.726900</td>
#       <td>2.620732</td>
#       <td>0.273681</td>
#       <td>0.041908</td>
#       <td>0.161841</td>
#       <td>0.241066</td>
#       <td>253.263701</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='86' max='630' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 86/630 10:28 < 1:07:02, 0.14 it/s]
#     </div>
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 256, 'num_beams': 8, 'length_penalty': 0.6, 'forced_eos_token_id': 1}

# %%
trainer.train(resume_from_checkpoint=f"{MODEL_NAME}/last-checkpoint")
# Out:
# There were missing keys in the checkpoint model loaded: ['model.encoder.embed_tokens.weight', 'model.decoder.embed_tokens.weight', 'lm_head.weight'].
#     <div>
#
#       <progress value='525' max='630' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [525/630 2:39:48 < 3:24:38, 0.01 it/s, Epoch 8.30/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>7</td>
#       <td>2.710900</td>
#       <td>2.615431</td>
#       <td>0.271269</td>
#       <td>0.040401</td>
#       <td>0.160898</td>
#       <td>0.238712</td>
#       <td>253.250993</td>
#     </tr>
#   </tbody>
# </table><p>
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 256, 'num_beams': 8, 'length_penalty': 0.6, 'forced_eos_token_id': 1}

# %%
trainer.train(resume_from_checkpoint=f"{MODEL_NAME}/last-checkpoint")
# Out:
# There were missing keys in the checkpoint model loaded: ['model.encoder.embed_tokens.weight', 'model.decoder.embed_tokens.weight', 'lm_head.weight'].
#     <div>
#
#       <progress value='631' max='630' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [630/630 3:15:12, Epoch 9.98/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>8</td>
#       <td>2.700400</td>
#       <td>2.611920</td>
#       <td>0.274069</td>
#       <td>0.041333</td>
#       <td>0.162430</td>
#       <td>0.241458</td>
#       <td>253.531374</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='68' max='630' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 68/630 08:20 < 1:09:59, 0.13 it/s]
#     </div>
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 256, 'num_beams': 8, 'length_penalty': 0.6, 'forced_eos_token_id': 1}

# %%
trainer.train(resume_from_checkpoint=f"{MODEL_NAME}/last-checkpoint")
# Out:
# There were missing keys in the checkpoint model loaded: ['model.encoder.embed_tokens.weight', 'model.decoder.embed_tokens.weight', 'lm_head.weight'].
#     <div>
#
#       <progress value='630' max='630' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [630/630 2:20:10, Epoch 9/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>9</td>
#       <td>2.667400</td>
#       <td>2.610904</td>
#       <td>0.272545</td>
#       <td>0.040774</td>
#       <td>0.161934</td>
#       <td>0.239920</td>
#       <td>253.127085</td>
#     </tr>
#   </tbody>
# </table><p>
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 256, 'num_beams': 8, 'length_penalty': 0.6, 'forced_eos_token_id': 1}
# TrainOutput(global_step=630, training_loss=0.26674346923828124, metrics={'train_runtime': 8465.4896, 'train_samples_per_second': 9.621, 'train_steps_per_second': 0.074, 'total_flos': 1.1755641495984538e+17, 'train_loss': 0.26674346923828124, 'epoch': 9.989933709796219})
